# %% [markdown]
# <a href="https://colab.research.google.com/github/saaraf1235-bot/Countries_Dataset_Session15_Assignment15/blob/main/Untitled1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files
import zipfile
import pandas as pd
import os

# 1. File upload karo
uploaded = files.upload()

# 2. Zip extract karo
for filename in uploaded.keys():
    with zipfile.ZipFile(filename, 'r') as zip_ref:
        zip_ref.extractall()

# 3. Dekho andar kya hai
print("Folder me ye files hain:")
# !ls

# 4. CSV find karke read karo
for file in os.listdir():
    if file.endswith('.csv'):
        print("\nCSV mil gayi:", file)
        df = pd.read_csv(file)
        print(df)
        break
# Out:
#      <input type="file" id="files-02ea378a-f80d-4563-831b-de4e8b75953f" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-02ea378a-f80d-4563-831b-de4e8b75953f">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
print(df)
# Out:
#     S.No.        Date  Score  Strike Rate Type of Match  Position  Innings  \
# 0       1  28-05-2010    114        95.79           ODI         4        1
# 1       2  30-05-2010    101       170.00           ODI         4        2
# 2       3  16-10-2013    141       114.63           ODI         1        2
# 3       4  02-11-2013    209       132.27           ODI         1        1
# 4       5  13-11-2014    264       152.60           ODI         2        1
# 5       6  18-01-2015    138        99.28           ODI         1        1
# 6       7  19-03-2015    137       108.73           ODI         1        1
# 7       8  11-10-2015    150       112.78           ODI         1        2
# 8       9  12-01-2016    171       104.90           ODI         1        1
# 9      10  15-01-2016    124        97.63           ODI         1        1
# 10     11  15-06-2017    123        95.34           ODI         1        2
# ...

# %%
df.head()
# Out:
#    S.No.        Date  Score  Strike Rate Type of Match  Position  Innings  \
# 0      1  28-05-2010    114        95.79           ODI         4        1
# 1      2  30-05-2010    101       170.00           ODI         4        2
# 2      3  16-10-2013    141       114.63           ODI         1        2
# 3      4  02-11-2013    209       132.27           ODI         1        1
# 4      5  13-11-2014    264       152.60           ODI         2        1
#
#   Dismissed  Man of the Match Captain    Against  \
# 0        Yes               No      No   Zimbabwe
# 1         No              Yes      No  Sri Lanka
# 2         No              Yes      No  Australia
# 3        Yes              Yes      No  Australia
# 4        Yes              Yes      No  Sri Lanka
#
#                                Venue    H/A/N Result
# 0       Queens Sports Club, Bulawayo     Away   Lost
# 1       Queens Sports Club, Bulawayo  Neutral    Won
# 2     Sawai Mansingh Stadium, Jaipur     Home    Won
# ...

# %%
df.tail()
# Out:
#     S.No.        Date  Score  Strike Rate Type of Match  Position  Innings  \
# 43     44  02-10-2015    106       160.60           T20         1        1
# 44     45  22-12-2017    118       274.41           T20         1        1
# 45     46  08-07-2018    100       178.57           T20         1        2
# 46     47  06-11-2018    111       181.96           T20         1        1
# 47     48  17-01-2024    121       175.36           T20         2        1
#
#    Dismissed  Man of the Match Captain       Against  \
# 43        Yes               No      No  South Africa
# 44        Yes              Yes     Yes     Sri Lanka
# 45         No              Yes      No       England
# 46         No              Yes     Yes   West Indies
# 47         No              Yes     Yes   Afghanistan
#
#                                 Venue H/A/N Result
# 43          HPCA Stadium, Dharamshala  Home   Lost
# 44     Holkar Cricket Stadium, Indore  Home    Won
# ...

# %%
df.sample(5)
# Out:
#     S.No.        Date  Score  Strike Rate Type of Match  Position  Innings  \
# 10     11  15-06-2017    123        95.34           ODI         1        2
# 39     40  09-02-2023    120        60.85          Test         1        2
# 8       9  12-01-2016    171       104.90           ODI         1        1
# 42     43  07-03-2024    103        64.37          Test         2        2
# 28     29  19-01-2020    119        92.96           ODI         1        2
#
#    Dismissed  Man of the Match Captain     Against  \
# 10         No              Yes      No  Bangladesh
# 39        Yes               No     Yes   Australia
# 8          No               No      No   Australia
# 42        Yes               No     Yes     England
# 28        Yes              Yes      No   Australia
#
#                                            Venue    H/A/N Result
# 10          Edgbaston Cricket Ground, Birmingham  Neutral    Won
# 39  Vidarbha Cricket Association Stadium, Nagpur     Home    Won
# ...

# %%
df.unique()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_3468/1660334235.py in <cell line: 0>()
# ----> 1 df.unique()
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/generic.py in __getattr__(self, name)
#    6297         ):
#    6298             return self[name]
# -> 6299         return object.__getattribute__(self, name)
#    6300
#    6301     @final
#
# AttributeError: 'DataFrame' object has no attribute 'unique'

# %%
df.value_counts()
# Out:
# S.No.  Date        Score  Strike Rate  Type of Match  Position  Innings  Dismissed   Man of the Match  Captain  Against       Venue                                               H/A/N    Result
# 1      28-05-2010  114    95.79        ODI            4         1        Yes         No                No       Zimbabwe      Queens Sports Club, Bulawayo                        Away     Lost      1
# 2      30-05-2010  101    170.00       ODI            4         2        No          Yes               No       Sri Lanka     Queens Sports Club, Bulawayo                        Neutral  Won       1
# 3      16-10-2013  141    114.63       ODI            1         2        No          Yes               No       Australia     Sawai Mansingh Stadium, Jaipur                      Home     Won       1
# 4      02-11-2013  209    132.27       ODI            1         1        Yes         Yes               No       Australia     M. Chinnaswamy Stadium, Bangalore                   Home     Won       1
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48 entries, 0 to 47
# Data columns (total 14 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   S.No.             48 non-null     int64
#  1   Date              48 non-null     object
#  2   Score             48 non-null     int64
#  3   Strike Rate       48 non-null     float64
#  4   Type of Match     48 non-null     object
#  5   Position          48 non-null     int64
#  6   Innings           48 non-null     int64
#  7   Dismissed         48 non-null     object
#  8   Man of the Match  48 non-null     object
#  9   Captain           48 non-null     object
#  10  Against           48 non-null     object
#  11  Venue             48 non-null     object
#  12  H/A/N             48 non-null     object
#  13  Result            48 non-null     object
# dtypes: float64(1), int64(4), object(9)
# memory usage: 5.4+ KB

# %%
df.describe()
# Out:
#        S.No.       Score  Strike Rate   Position    Innings
# count  48.00   48.000000    48.000000  48.000000  48.000000
# mean   24.50  134.937500   109.656042   1.708333   1.541667
# std    14.00   34.744298    41.704401   1.320192   0.581939
# min     1.00  100.000000    50.560000   1.000000   1.000000
# 25%    12.75  111.000000    85.197500   1.000000   1.000000
# 50%    24.50  124.500000   105.710000   1.000000   1.500000
# 75%    36.25  147.750000   121.100000   2.000000   2.000000
# max    48.00  264.000000   274.410000   6.000000   3.000000

# %%
df.columns
# Out:
# Index(['S.No.', 'Date', 'Score', 'Strike Rate', 'Type of Match', 'Position',
#        'Innings', 'Dismissed ', 'Man of the Match', 'Captain', 'Against',
#        'Venue', 'H/A/N', 'Result'],
#       dtype='object')

# %%
df.shape
# Out:
# (48, 14)

# %%
df.value_counts()
# Out:
# S.No.  Date        Score  Strike Rate  Type of Match  Position  Innings  Dismissed   Man of the Match  Captain  Against       Venue                                               H/A/N    Result
# 1      28-05-2010  114    95.79        ODI            4         1        Yes         No                No       Zimbabwe      Queens Sports Club, Bulawayo                        Away     Lost      1
# 2      30-05-2010  101    170.00       ODI            4         2        No          Yes               No       Sri Lanka     Queens Sports Club, Bulawayo                        Neutral  Won       1
# 3      16-10-2013  141    114.63       ODI            1         2        No          Yes               No       Australia     Sawai Mansingh Stadium, Jaipur                      Home     Won       1
# 4      02-11-2013  209    132.27       ODI            1         1        Yes         Yes               No       Australia     M. Chinnaswamy Stadium, Bangalore                   Home     Won       1
# ...

# %%
df.isnull().sum()
# Out:
# S.No.               0
# Date                0
# Score               0
# Strike Rate         0
# Type of Match       0
# Position            0
# Innings             0
# Dismissed           0
# Man of the Match    0
# Captain             0
# Against             0
# Venue               0
# H/A/N               0
# Result              0
# dtype: int64
